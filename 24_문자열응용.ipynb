# %%
# 문자열 바꾸기

"Hello World".replace("World", "python")
# Out:
# 'Hello python'

# %%
# 문자 바꾸기
table = str.maketrans("aeiou","12345")
'apple'.translate(table)
# Out:
# '1ppl2'

# %%
# 문자열 분리하기

'apple pear grape pineaoole orange'.split()
# Out:
# ['apple', 'pear', 'grape', 'pineaoole', 'orange']

# %%
"apple, pear, grape, pineaoole, orange".split(', ')
# Out:
# ['apple', 'pear', 'grape', 'pineaoole', 'orange']

# %%
#구분자 문자열과 문자열 리스트 연결하기
" ".join(["apple", "pear", "grape","pineapple","orange"])
# Out:
# 'apple pear grape pineapple orange'

# %%
"-".join(["apple", "pear", "grape","pineapple","orange"])
# Out:
# 'apple-pear-grape-pineapple-orange'

# %%
# 소문자를 대문자로 바꾸기
"python".upper()
# Out:
# 'PYTHON'

# %%
# 대문자를 소문자로 바꾸기
"PYTHON".lower()
# Out:
# 'python'

# %%
#왼 오 양 공백 삭제 하기

"   python  ".lstrip()
# Out:
# 'python  '

# %%
"   python  ".rstrip()
# Out:
# '   python'

# %%
"   python  ".strip()
# Out:
# 'python'

# %%
#특정문자 삭제하기
", python.".lstrip(",.")
# Out:
# ' python.'

# %%
", python.".strip(",.").strip()
# Out:
# 'python'

# %%
## 문자열을 왼쪽 정렬하기

"python".ljust(10)
# Out:
# 'python    '

# %%
## 문자열을 오른족으로 정렬하기
"python".rjust(10)
# Out:
# '    python'

# %%
##문자열을 가운데 정렬하기
"python".center(10)
# Out:
# '  python  '

# %%
## 메서드 체이닝

"python".rjust(10).upper()
# Out:
# '    PYTHON'

# %%
##문자열 왼쪽에 0채우기
"35".zfill(4)
# Out:
# '0035'

# %%
##문자열 위치 찾기
"apple pineallpe".find("pl")
# Out:
# 2

# %%
"apple pineallpe".rfind("pl")
# Out:
# 2

# %%
"apple pineallpe".rfind("xy")
# Out:
# -1

# %%
"apple pineallpe".index("pl")
# Out:
# 2

# %%
##문자열 개수 세기
"apple pinealple".count("pl")
# Out:
# 2

# %%
## 문자열 서식 지정자와 포매팅 사용

"I am %s." % "james"
# Out:
# 'I am james.'

# %%
name = "maria"
"I am %s." %name
# Out:
# 'I am maria.'

# %%
##서식 지정자로 숫자 넣기

"I am %d years old." % 20
# Out:
# 'I am 20 years old.'

# %%
## 서식 지정자로 소수점 표현
"%f " %2.3
# Out:
# '2.300000 '

# %%
"%.2f" % 2.3
# Out:
# '2.30'

# %%
"%.3f" %2.3
# Out:
# '2.300'

# %%
#서식 지정자로 문자열 정렬하기
"%10s" %"python"
# Out:
# '    python'

# %%
'%-10s' % 'python'
# Out:
# 'python    '

# %%
#서식 지정자로 문자열 안에 값 여러개 넣기

"Today is %d %s." %(3,'April')
# Out:
# 'Today is 3 April.'

# %%
"Today is %d%s." %(3,'April')
# Out:
# 'Today is 3April.'

# %%
#format 메서드 사용

'Hello, {0}'.format('world!')
# Out:
# 'Hello, world!'

# %%
'Hello, {0}'.format(100)
# Out:
# 'Hello, 100'

# %%
##format 메서드로 같은 값을 여러개 넣기
'{0} {0} {1} {1}'.format('python','script')
# Out:
# 'python python script script'

# %%
## format 메서드에서 인덱스 대신 이름 지정하기

"hello, {language} {version}".format(language = "python",version=3.6)
# Out:
# 'hello, python 3.6'

# %%
#format 메서드로 인덱스 생략하기
"hello, {} {} {}".format("python","script", 3.6)
# Out:
# 'hello, python script 3.6'
