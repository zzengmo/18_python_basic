# %%
# 세미콜론

print("hello world");
# Out:
# hello world

# %%
# 한 줄 주석
# 출력하라
print("hello world")
# Out:
# hello world

# %%
# 블록 주석
# 컨트롤 + / 단축키로 블록 주석을 만들 수 있다.

# print("hello world")
# print("hello world")
# print("hello world")

# %%
# 들여쓰기

a = 5

if a == 10:
    print("10입니다")
else:
    print("틀렸습니다")
# Out:
# 틀렸습니다
