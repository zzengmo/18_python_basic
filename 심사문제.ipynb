# %%
# 3.8 문자열 출력하기

print("Hello, world!")
print("Hello, world!")

# %%
#5.6 스킬 공격력 출력하기

AP = 102

print(AP * 0.6 + 225)

# %%
#6.7 변수 만들기

a = 50
b = 100
c = None

print(a)
print(b)
print(c)

# %%
#6.8 평균 점수 구하기

k,e,m,s = map(int, input("국어,영어,수학,과학 점수를 입력하시오: ").split())

print((k+e+m+s) // 4)

# %%
#7.5 날짜와 시간 출력하기

year,month,day,hour,minute,second = input().split()

print(year,month,day, sep="-",end="T")
print(hour,minute,second, sep=":" )

# %%
#8.5 합격 여부 출력하기

korean,english,mathematics,science = map(int,input("점수를 입력하시오: ").split())
print(korean >= 90 and english > 80 and mathematics > 85 and science >= 80)

# %%
#9.4 여러줄로 된 문자열 사용하기

s = """'Python' is a "programming language"
that lets you work quickly
and
integrate systems more effectively."""

print(s)

# %%
#10.5 range로 튜플 만들기

a = int(input("증가 숫자를 입력하세요: "))
print(tuple(range(-10, 10,a)))

# %%
# 11.7 연습문제
n = -32,75,97,-10,9,32,4,-15,0,76,14,2

n[1::2]

# %%
#11.8 리스트의 마지막 부분 5개 삭제하기

x = input().split()

del x[-5:]
tuple(x)

# %%
#11.9 문자열에서 인덱스가 홀수인 문자와 짝수인 문자 연결하기

s1 = input("첫 번째 문자열을 입력하시오: ") 
s2 = input("두 번째 문자열을 입력하시오: ") 
print(s1[1::2] + s2[::2])

# %%
#12.4 연습문제

camile = {
    "health" : 575.6,
    "health_regen" : 1.7,
    "mana": 338.8,
    "mana_regen": 1.63,
    "melee": 125,
    "attack_damage":60,
    "attack_speed":0.625,
    "armor": 26,
    "magic_resistance": 32.1,
    "movement_speed": 340
}

print(

)

print(camile["health"])
print(camile["movement_speed"])

# %%
#12.5 심사문제 딕셔너리에 게임 캐릭터 능력치 저장하기


s1 = input().split()
s2 = input().split()

character_stats = dict(zip(s1, s2))
print(character_stats)

# %%
#13.6 연습문제

x = 5

if x == 5:
    print("ok")

if x != 10:
    print('ok')

# %%
#13.7 심사문제 온라인 할인 쿠폰 시스템 만들기

x = int(input())
coupon = input()

if coupon == "Cash3000":
    print(x - 3000)

if coupon == "Cash5000":
    print(x - 5000)

# %%
#14.6 연습문제

written_test = 75
coding_test = True

if (written_test >= 80 and coding_test == True):
    print("합격")
else:
    print("불합격")

# %%
#14.7 심사문제 합격 여부 판단하기

k,e,m,s = map(int,input().split())

if not (0 <= k <= 100 and 0 <= e <= 100 and 0 <= m <= 100 and 0 <= s <= 100):
        print("잘못된 점수")

else:
    if (k + e + m + s) / 4 >= 80:
        print("합격")
    else:
        print("불합격")

# %%
#15.3 연습문제 

x = int(input())

if (11 < x <20):
    print("11~20")
elif (21 < x < 30 ):
    print("21~30")
else:
    print("아무것도 해당하지 않음")

# %%
#15.4 심사문제 교통카드 시스템 만들기

balance = 9000
age = int(input())

if (7 < age <= 12):
    print(" 요금 650원입니다.\n","남은잔액",balance - 650,"원 남앗습니다")
elif (13 <= age <= 18):
    print(" 요금 1050원 입니다.\n","남은잔액",balance - 1050,"원 남앗습니다")
elif (19 <= age ):
    print(" 요금 1250원입니다.\n","남은잔액",balance - 1250,"원 남앗습니다")
else:
    print("무료입니다.")

# %%
#15.4 심사문제 교통카드 시스템 만들기
age = int(input())
balance = 9000

if (7 <= age <= 12):
    print(balance - 650)
elif (13 <= age <= 18):
    print(balance - 1050)
elif (19 <= age ):
    print(balance - 1250)
else:
    print("무료입니다.")

# %%
#16.5 연습문제

x = [49,-17,25,102,8,62,21]

for i in x:
    print(i * 10, end=" ")

# %%
#16.6 심사문제 구구단 출력하기


a = int(input())

for i in range(1,10):
    print(a, "*", i, "=", a * i)

# %%
#17.5 연습문제

i = 2
j = 5

while i <= 32 or j >=1:
    print(i,j)
    i *= 2
    j -= 1

# %%
#17.6 심사문제 교통카드 잔액 출력하기

a = int(input()) #내 잔액 입력
b = 1350 # 1회당 요금 

while a >= b:
    a -= b
    print(a)

# %%
#18.5 연습문제

i = 0
while True:
    if i % 10 != 3:
        i += 1
        continue
    if i > 73:
        break
    print(i, end=' ')
    i += 1

# %%
# 18.6 심사문제 두 수 사이의 숫자 중 3으로 끝나지 않는 숫자 출력하기

start, stop = map(int,input().split())

i = start

while True:
    if i % 10 == 3:
        i += 1
        continue
    if i > stop:
        break
    print(i, end=' ')
    i += 1

# %%
#19.5 연습문제 역삼각형 모양 별출력

for i in range(5):
    for j in range(5):
        if j < i:
            print(" ", end="")
        else:
            print("*", end="")
    print()

# %%
##19.6 심사문제 산 모양으로 별 출력하기

x = int(input())

for i in range(1,x + 1):
    for j in range(1, x * 2):
        if x - i + 1 <= j <= x + i - 1:
            print("*", end="")
        else:
            print(" ", end="")
    print()

# %%
x = int(input())

for i in range(x):
    print((" " * (4 - i)) + "*" * (2 * i + 1) )

# %%
# 연습문제 20.7

for i in range(1,101):
    if i % 2 == 0 and i % 11 == 0:
        print("fizzbuzz")
    elif i % 2 == 0:
        print('Fizz')
    elif i % 11 == 0:
        print("Buzz")
    else:
        print(i)

# %%
#심사문제 20.8 5와 7의 배수 공배수 처리하기

a , b = map(int,input().split())

for i in range(a, b + 1):
    if i % 5 == 0 and i % 7 == 0:
        print("fizzbuzz")
    elif i % 5 == 0:
        print('Fizz')
    elif i % 7 == 0:
        print("Buzz")
    else:
        print(i)

# %%
## 22.9 연습문제

a = ["alpha", "bravo", "charlie", "delta", "echo", "foxtrot", "golf","hotel", "inida"]
b = [i for i in a if len(i) == 5]
print(b)

# %%
## 22.10 심사문제 2의 거듭제곱 리스트 생성하기

a,b = map(int,input().split())

c = [2 ** i for i in range(a,b + 1)]
del c[1]
del c[-2]
print(c)

# %%
#23.6 연습문제 

a = [[[0 for col in range(3)] for row in range(4)] for depth in range(2)]

print(a)

# %%
#23.7 심사문제 지뢰찾기

col,row = map(int,input().split()) 

matrix = []

for i in range(row):
    matrix.append(list(input()))

for i in range(row):
    for j in range(col):
        if matrix[i][j] == "*":
            continue
        count = 0
        for x in range(-1, 2):
            for y in range(-1, 2):
                ni = i + x
                nj = j + y
                if 0 <= ni < row and 0 <= nj < col:
                    if matrix[ni][nj] == "*":
                        count += 1
        matrix[i][j] = str(count)
    for ch in matrix[i]:      
        print(ch, end="")     
    print()

# %%
## 24.4 연습문제

path = 'C:\\Users\\dojang\\AppData\\Local\\Programs\\Python\\Python36-32\\python.exe'

x = path.split('\\')
filename = x[-1]

# %%
#24.5 심사문제 특정 단어 개수 세기

text = input().split()

count = 0
for word in text:
    if word == "the":
        count += 1

print(count)

# %%
#24.6 심사문제 높은 가격순으로 출력하기

prices = list(map(int,input().split(';')))
prices.sort(reverse=True)

for i in prices:
    print(f"{i:>9,}")

# %%
#25.7 연습문제

maria = {'korean': 94, 'english': 91, 'mathematics':89, 'science': 83}

average = sum(maria.values()) / len(maria)

print(average)

# %%
#25.8 심사문제 딕셔너리에서 특정 값 삭제하기


keys = input().split()
values = list(map(int,input().split()))

x = dict(zip(keys, values))

for key in list(x.keys()):
    if key == 'delta' or x[key] == 30:
        del x[key]

print(x)

# %%
{key: value for key, value in x.items() if key != "delta" and value != 30}

# %%
#26.8 연습문제

a = {i for i in range(1,101) if i % 3 ==0 }
b = {i for i in range(1,101) if i % 5 ==0 }

print(a & b)

# %%
#26.9 심사문제 두숫자의 공약수를 세트 형태로 구하고 최종 결과는공약수의 합

a,b = list(map(int,input().split()))

a = set(i for i in range(1,a + 1) if a % i == 0)
b = set(i for i in range(1,b + 1) if b % i == 0)

divisor = a & b
result = 0
if type(divisor) == set:
    result = sum(divisor)

print(result)

# %%
#29.7 연습문제

x = 10
y = 3

def get_quotient_remainder(a,b):
    return a // b, a % b 

quotient,remainder = get_quotient_remainder(x,y)
print('몫: {0}, 나머지: {1}'.format(quotient,remainder))

# %%
# 29.8 심사문제 사칙 연산 함수 만들기

x,y = map(int,input().split())

def calc(a,b):
    return a + b, a - b, a * b, a / b

a,s,m,d = calc(x,y)
print('덧셈:{0}, 뻴셈: {1},곱셈: {2},나눈셈:{3}'.format(a,s,m,d))

# %%
#30.6 연습문제

korean,english,mathematics,science = 100,86,81,91

def get_max_score(*args):
    return max(args)


max_score = get_max_score(korean,english,mathematics,science)
print('높은 점수:', max_score)

max_score = get_max_score(english,science)
print('높은 점수:', max_score)

# %%
#30.7 심사문제 가장 낮은 점수 높은 점수와 평균 점수를 구하는 함수 만들기

korean, english, mathematics,science = map(int,input().split())

def get_min_max_score(*args):
    return min(args), max(args)

def get_average(**kwargs):
    total = sum(kwargs.values())
    return total / len(kwargs)

min_score, max_score = get_min_max_score(korean,english,mathematics,science)
average_score = get_average(korean=korean, english = english,
                            mathematics = mathematics, science = science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'
        .format(min_score,max_score, average_score))

min_score, max_score = get_min_max_score(english,science)
average_score = get_average(english=english, science=science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'.format(min_score,max_score,average_score))

# %%
#31.4 연습문제

def is_palindrome(word):

    if len(word) < 2:
        return True
    if word[0] != word[-1]:
        return False
    return is_palindrome(word[1:-1])

print(is_palindrome('hello'))
print(is_palindrome('level'))

# %%
#31.5심사문제 재귀호출로 피보나치 수 구하기

def fib(n):
    if n <= 1:
        return n
    else:
        return fib(n - 1) + fib(n - 2)


n = int(input())
print(fib(n))

# %%
#32.4 연습문제

files = ['font','1.png','10.jpg','11.gif','2.jpg','3.png','table.xslx','sepc.docx']

print(list(filter(lambda x: x.find('jpg') != -1 or x.find('.png') != -1,files)))

# %%
#32.5 심사문제 파일 이름을 한꺼번에 바꾸기 1.jpg -> 001.jpg, 10.png -> 010.png, 100.gif -> 100.gif
#파일 이름이 숫자 3개면서 앞에 0이 들어가야함
#람다식 표현 출력 결과는 리스트 형태
#문자열 포매팅과 문자열 메서드 사용



files = input().split()

result = list(map(lambda x: x.split('.')[0].zfill(3) + '.' + x.split('.')[1], files))

print(result)
# Out:
# ['001.jpg', '010.png']

# %%
#34.5 연습문제
class Knight:
    def __init__(self,health,mana,armor):
        self.health = health
        self.mana = mana
        self.armor = armor

    def slash(self):
        print('베기')

x = Knight(health=542.4, mana=210.3, armor=38)
print(x.health, x.mana, x.armor)
x.slash()
# Out:
# 542.4 210.3 38
# 베기

# %%
#34.6 심사문제 게임캐릭터 클래스 만들기

class Annie:
    def __init__(self,health,mana,ability_power):
        self.health = health
        self.mana = mana
        self.ability_power = ability_power

    def tibbers(self):
        print("티버: 피해량",ability_power * 0.65 + 400)


health, mana, ability_power = map(float,input().split())

x = Annie(health= health, mana=mana, ability_power=ability_power)
x.tibbers()
# Out:
# 티버: 피해량 593.7
