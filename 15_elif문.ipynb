# %%
# elif 사용하기

# if 조건식:
#     수행할코드
# elif 조건식2:
#     수행할코드2
# else:
#     수행할코드3

x = 20

if x == 10:
    print("10입니다.")
elif x == 20:
    print("20입니다.")
# Out:
# 20입니다.

# %%
x = 215

if x == 10:
    print("10입니다.")
elif x == 20:
    print("20입니다.")
else:
    print("만족안합니다")
# Out:
# 만족안합니다

# %%
x = 30

if x == 10:
    print("10입니다.")
elif x == 20:
    print("20입니다.")
else:
    print("10도 아니고 20도 아닙니다")
# Out:
# 10도 아니고 20도 아닙니다

# %%
# 잘못된 문법
# if x == 10:
#     print('10입니다.')
# else:
#     print("10 or 20 아닙니다.")
# elif x == 20:
# print("20입니다.")

# %%
button = int(input("1,2,3 중에 고르시오"))

if button == 1:
    print("콜라")
elif button == 2:
    print("사이다")
elif button == 3:
    print("환타")
else:
    print("제공하지 않는 메뉴")
# Out:
# 제공하지 않는 메뉴
