# %%
# if 조건문 사용하기

# if 조건식:
#     코드

x = 10

if (x == 10):
    print("10입니다")
# Out:
# 10입니다

# %%
#if 조건문을 사용할 때 주의할 점!
# if x = 10:  << 툴림

# %%
#if 조건문에서 코드를 생략하기
x = 10
if x == 10:
    pass

# %%
#if 조건문과 들여쓰기

x = 10

if x == 10:
    print("x에 들어있는 숫자는")
    print("10입니다.")
# Out:
# x에 들어있는 숫자는
# 10입니다.

# %%
x = 10

if x == 10:
    print("x에 들어있는 숫자는")
    
print("10입니다.")
# Out:
# x에 들어있는 숫자는
# 10입니다.

# %%
# 중첩 if문 사용하기

x = 15

if x >= 10:
    print("10이상입니다.")

    if x == 15:
        print("15입니다.")

    if x == 20:
        print("20입니다.")
# Out:
# 10이상입니다.
# 15입니다.

# %%
# "사용자가 입력한 값에 if 조건문 사용하기

x = int(input())

if x == 10:
    print("10입니다.")

if x == 20:
    print("20입니다.")
# Out:
# 20입니다.
